# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 742

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
time.sleep(60)
i=0

# Create endpoint URL with each city.
city_url = url + "&q=" + cities[i]
    
 # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1   
 # Run an API request for each of the cities.   
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | kaiyuan
# Processing Record 3 of Set 1 | juba
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | tessalit
# Processing Record 6 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | bukan
# Processing Record 9 of Set 1 | kodiak
# Processing Record 10 of Set 1 | nouadhibou
# Processing Record 11 of Set 1 | dharchula
# Processing Record 12 of Set 1 | vao
# Processing Record 13 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 1 | wilmington
# Processing Record 15 of Set 1 | howard springs
# Processing Record 16 of Set 1 | hovd
# Processing Record 17 of Set 1 | les cayes
# Processing Record 18 of Set 1 | porto belo
# Processing Record 19 of Set 1 | santa rosa
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | hofn
# Processing Record 22 of Set 1 | ribeira grande
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | port elizabeth
# Processing Record 25 of Set 1 | abu samrah
# Processing Record 26 of Set 1 | pundaguitan
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | chokurdakh
# Processing Record 29 of Set 1 | saint george
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | dingle
# Processing Record 32 of Set 1 | novyy urengoy
# Processing Record 33 of Set 1 | tuktoyaktuk
# Processing Record 34 of Set 1 | loralai
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | etne
# Processing Record 38 of Set 1 | puerto ayora
# Processing Record 39 of Set 1 | san onofre
# Processing Record 40 of Set 1 | ostrovnoy
# Processing Record 41 of Set 1 | upernavik
# Processing Record 42 of Set 1 | cabo san lucas
# Processing Record 43 of Set 1 | lilongwe
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | paungde
# Processing Record 47 of Set 1 | arraial do cabo
# Processing Record 48 of Set 1 | kirkland lake
# Processing Record 49 of Set 1 | hambantota
# Processing Record 50 of Set 1 | saldanha
# Processing Record 1 of Set 2 | avarua
# Processing Record 2 of Set 2 | ponta do sol
# Processing Record 3 of Set 2 | clyde river
# Processing Record 4 of Set 2 | carnarvon
# Processing Record 5 of Set 2 | norman wells
# Processing Record 6 of Set 2 | portobelo
# Processing Record 7 of Set 2 | nikolskoye
# Processing Record 8 of Set 2 | nhulunbuy
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | bredasdorp
# Processing Record 11 of Set 2 | thompson
# Processing Record 12 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 2 | coihaique
# Processing Record 14 of Set 2 | porto novo
# Processing Record 15 of Set 2 | pevek
# Processing Record 16 of Set 2 | punta arenas
# Processing Record 17 of Set 2 | chernyshevskiy
# Processing Record 18 of Set 2 | yanan
# City not found. Skipping...
# Processing Record 19 of Set 2 | bluff
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | cayenne
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | hermanus
# Processing Record 24 of Set 2 | qaqortoq
# Processing Record 25 of Set 2 | biharamulo
# Processing Record 26 of Set 2 | dikson
# Processing Record 27 of Set 2 | irbit
# Processing Record 28 of Set 2 | gilgit
# Processing Record 29 of Set 2 | sundargarh
# Processing Record 30 of Set 2 | temaraia
# City not found. Skipping...
# Processing Record 31 of Set 2 | chalmette
# Processing Record 32 of Set 2 | bilma
# Processing Record 33 of Set 2 | souillac
# Processing Record 34 of Set 2 | nanortalik
# Processing Record 35 of Set 2 | hithadhoo
# Processing Record 36 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 2 | tapaua
# City not found. Skipping...
# Processing Record 38 of Set 2 | torbay
# Processing Record 39 of Set 2 | acapulco
# Processing Record 40 of Set 2 | port blair
# Processing Record 41 of Set 2 | belaya gora
# Processing Record 42 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 2 | emba
# Processing Record 44 of Set 2 | port lincoln
# Processing Record 45 of Set 2 | gurupi
# Processing Record 46 of Set 2 | verkhnevilyuysk
# Processing Record 47 of Set 2 | broken hill
# Processing Record 48 of Set 2 | faanui
# Processing Record 49 of Set 2 | chuy
# Processing Record 50 of Set 2 | constitucion
# Processing Record 1 of Set 3 | mataura
# Processing Record 2 of Set 3 | puerto del rosario
# Processing Record 3 of Set 3 | vaini
# Processing Record 4 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 3 | poya
# Processing Record 6 of Set 3 | finspang
# Processing Record 7 of Set 3 | aquin
# Processing Record 8 of Set 3 | peniche
# Processing Record 9 of Set 3 | pangnirtung
# Processing Record 10 of Set 3 | baruun-urt
# Processing Record 11 of Set 3 | asau
# Processing Record 12 of Set 3 | porto santo
# Processing Record 13 of Set 3 | enid
# Processing Record 14 of Set 3 | east london
# Processing Record 15 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 3 | fortuna
# Processing Record 17 of Set 3 | ushuaia
# Processing Record 18 of Set 3 | komsomolskiy
# Processing Record 19 of Set 3 | the valley
# Processing Record 20 of Set 3 | uige
# Processing Record 21 of Set 3 | saint cloud
# Processing Record 22 of Set 3 | washington
# Processing Record 23 of Set 3 | castro
# Processing Record 24 of Set 3 | cidreira
# Processing Record 25 of Set 3 | buchanan
# Processing Record 26 of Set 3 | tammisaari
# Processing Record 27 of Set 3 | deniliquin
# Processing Record 28 of Set 3 | barrow
# Processing Record 29 of Set 3 | puerto escondido
# Processing Record 30 of Set 3 | yar-sale
# Processing Record 31 of Set 3 | barabinsk
# Processing Record 32 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 3 | narsaq
# Processing Record 34 of Set 3 | carsamba
# Processing Record 35 of Set 3 | maine-soroa
# Processing Record 36 of Set 3 | dipkarpaz
# City not found. Skipping...
# Processing Record 37 of Set 3 | port hedland
# Processing Record 38 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 3 | ambilobe
# Processing Record 40 of Set 3 | nabire
# Processing Record 41 of Set 3 | lebu
# Processing Record 42 of Set 3 | belle fourche
# Processing Record 43 of Set 3 | lufilufi
# Processing Record 44 of Set 3 | west wendover
# Processing Record 45 of Set 3 | grand gaube
# Processing Record 46 of Set 3 | kahului
# Processing Record 47 of Set 3 | gari
# Processing Record 48 of Set 3 | aitape
# Processing Record 49 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 3 | provideniya
# Processing Record 1 of Set 4 | rovnoye
# Processing Record 2 of Set 4 | lao cai
# Processing Record 3 of Set 4 | road town
# Processing Record 4 of Set 4 | martapura
# Processing Record 5 of Set 4 | baykit
# Processing Record 6 of Set 4 | vestmanna
# Processing Record 7 of Set 4 | zhigansk
# Processing Record 8 of Set 4 | idenao
# Processing Record 9 of Set 4 | longyearbyen
# Processing Record 10 of Set 4 | bilibino
# Processing Record 11 of Set 4 | tsumeb
# Processing Record 12 of Set 4 | celestun
# Processing Record 13 of Set 4 | mountain home
# Processing Record 14 of Set 4 | hamilton
# Processing Record 15 of Set 4 | khash
# Processing Record 16 of Set 4 | jefferson city
# Processing Record 17 of Set 4 | great bend
# Processing Record 18 of Set 4 | hilo
# Processing Record 19 of Set 4 | mar del plata
# Processing Record 20 of Set 4 | haverhill
# Processing Record 21 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 4 | itarema
# Processing Record 23 of Set 4 | aracuai
# Processing Record 24 of Set 4 | vardo
# Processing Record 25 of Set 4 | xichang
# Processing Record 26 of Set 4 | port-gentil
# Processing Record 27 of Set 4 | inhambane
# Processing Record 28 of Set 4 | vostok
# Processing Record 29 of Set 4 | bathsheba
# Processing Record 30 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 4 | sao filipe
# Processing Record 32 of Set 4 | mugur-aksy
# Processing Record 33 of Set 4 | iqaluit
# Processing Record 34 of Set 4 | san quintin
# Processing Record 35 of Set 4 | avera
# Processing Record 36 of Set 4 | axim
# Processing Record 37 of Set 4 | jiwani
# Processing Record 38 of Set 4 | ponta delgada
# Processing Record 39 of Set 4 | humaita
# Processing Record 40 of Set 4 | lensk
# Processing Record 41 of Set 4 | paramonga
# Processing Record 42 of Set 4 | magistralnyy
# Processing Record 43 of Set 4 | makakilo city
# Processing Record 44 of Set 4 | thinadhoo
# Processing Record 45 of Set 4 | iberia
# Processing Record 46 of Set 4 | batemans bay
# Processing Record 47 of Set 4 | pyay
# Processing Record 48 of Set 4 | naze
# Processing Record 49 of Set 4 | moerai
# Processing Record 50 of Set 4 | pombia
# Processing Record 1 of Set 5 | leningradskiy
# Processing Record 2 of Set 5 | bethel
# Processing Record 3 of Set 5 | poum
# Processing Record 4 of Set 5 | charlestown
# Processing Record 5 of Set 5 | denia
# Processing Record 6 of Set 5 | lagoa
# Processing Record 7 of Set 5 | svetlyy
# Processing Record 8 of Set 5 | fougamou
# Processing Record 9 of Set 5 | hualmay
# Processing Record 10 of Set 5 | severo-kurilsk
# Processing Record 11 of Set 5 | ambon
# Processing Record 12 of Set 5 | copala
# Processing Record 13 of Set 5 | pershotravneve
# Processing Record 14 of Set 5 | sioux lookout
# Processing Record 15 of Set 5 | tobermory
# Processing Record 16 of Set 5 | kaitangata
# Processing Record 17 of Set 5 | katsuura
# Processing Record 18 of Set 5 | lumphat
# Processing Record 19 of Set 5 | bridgetown
# Processing Record 20 of Set 5 | ilulissat
# Processing Record 21 of Set 5 | beloha
# Processing Record 22 of Set 5 | newport
# Processing Record 23 of Set 5 | sobolevo
# Processing Record 24 of Set 5 | valls
# Processing Record 25 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 5 | tumaco
# Processing Record 27 of Set 5 | loreto
# Processing Record 28 of Set 5 | benalla
# Processing Record 29 of Set 5 | kamiiso
# Processing Record 30 of Set 5 | florianopolis
# Processing Record 31 of Set 5 | rosetown
# Processing Record 32 of Set 5 | yellowknife
# Processing Record 33 of Set 5 | manokwari
# Processing Record 34 of Set 5 | saint stephen
# Processing Record 35 of Set 5 | igurubi
# Processing Record 36 of Set 5 | sarakhs
# Processing Record 37 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 5 | marinette
# Processing Record 39 of Set 5 | gambela
# Processing Record 40 of Set 5 | itaberai
# Processing Record 41 of Set 5 | brae
# Processing Record 42 of Set 5 | tura
# Processing Record 43 of Set 5 | hobart
# Processing Record 44 of Set 5 | cosio
# Processing Record 45 of Set 5 | mahebourg
# Processing Record 46 of Set 5 | bucerias
# Processing Record 47 of Set 5 | yemtsa
# Processing Record 48 of Set 5 | luneville
# Processing Record 49 of Set 5 | chinsali
# Processing Record 50 of Set 5 | diego de almagro
# Processing Record 1 of Set 6 | alofi
# Processing Record 2 of Set 6 | tacoronte
# Processing Record 3 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 6 | swakopmund
# Processing Record 5 of Set 6 | upington
# Processing Record 6 of Set 6 | cherskiy
# Processing Record 7 of Set 6 | ukiah
# Processing Record 8 of Set 6 | sawtell
# Processing Record 9 of Set 6 | bengkulu
# Processing Record 10 of Set 6 | shakiso
# Processing Record 11 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 12 of Set 6 | olinda
# Processing Record 13 of Set 6 | vaitape
# Processing Record 14 of Set 6 | tuatapere
# Processing Record 15 of Set 6 | znamenka
# Processing Record 16 of Set 6 | yershov
# Processing Record 17 of Set 6 | naral
# City not found. Skipping...
# Processing Record 18 of Set 6 | yakeshi
# Processing Record 19 of Set 6 | talnakh
# Processing Record 20 of Set 6 | namibe
# Processing Record 21 of Set 6 | diu
# Processing Record 22 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 6 | honningsvag
# Processing Record 24 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 6 | jalu
# Processing Record 26 of Set 6 | abja-paluoja
# Processing Record 27 of Set 6 | totma
# Processing Record 28 of Set 6 | mount isa
# Processing Record 29 of Set 6 | lewistown
# Processing Record 30 of Set 6 | marseille
# Processing Record 31 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 6 | mufumbwe
# Processing Record 33 of Set 6 | portsmouth
# Processing Record 34 of Set 6 | mimoso do sul
# Processing Record 35 of Set 6 | yumen
# Processing Record 36 of Set 6 | springdale
# Processing Record 37 of Set 6 | vila
# Processing Record 38 of Set 6 | boda
# Processing Record 39 of Set 6 | bonthe
# Processing Record 40 of Set 6 | harper
# Processing Record 41 of Set 6 | kloulklubed
# Processing Record 42 of Set 6 | kamakwie
# Processing Record 43 of Set 6 | gushikawa
# Processing Record 44 of Set 6 | ingleside
# Processing Record 45 of Set 6 | newburgh
# Processing Record 46 of Set 6 | broome
# Processing Record 47 of Set 6 | nanakuli
# Processing Record 48 of Set 6 | hami
# Processing Record 49 of Set 6 | cravo norte
# Processing Record 50 of Set 6 | bambous virieux
# Processing Record 1 of Set 7 | talas
# Processing Record 2 of Set 7 | mitsamiouli
# Processing Record 3 of Set 7 | kavaratti
# Processing Record 4 of Set 7 | leninskoye
# Processing Record 5 of Set 7 | pacific grove
# Processing Record 6 of Set 7 | nola
# Processing Record 7 of Set 7 | laguna
# Processing Record 8 of Set 7 | kavieng
# Processing Record 9 of Set 7 | dingzhou
# Processing Record 10 of Set 7 | mogadishu
# Processing Record 11 of Set 7 | luanda
# Processing Record 12 of Set 7 | dupnica
# City not found. Skipping...
# Processing Record 13 of Set 7 | alice springs
# Processing Record 14 of Set 7 | oksfjord
# Processing Record 15 of Set 7 | bonavista
# Processing Record 16 of Set 7 | nelson bay
# Processing Record 17 of Set 7 | camacha
# Processing Record 18 of Set 7 | carutapera
# Processing Record 19 of Set 7 | lompoc
# Processing Record 20 of Set 7 | sao miguel do araguaia
# Processing Record 21 of Set 7 | usak
# Processing Record 22 of Set 7 | kachiry
# Processing Record 23 of Set 7 | xinyu
# Processing Record 24 of Set 7 | richards bay
# Processing Record 25 of Set 7 | portland
# Processing Record 26 of Set 7 | jining
# Processing Record 27 of Set 7 | sitka
# Processing Record 28 of Set 7 | georgetown
# Processing Record 29 of Set 7 | black diamond
# Processing Record 30 of Set 7 | kottagudem
# Processing Record 31 of Set 7 | pochutla
# Processing Record 32 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 7 | nemuro
# Processing Record 34 of Set 7 | veseloyarsk
# Processing Record 35 of Set 7 | touros
# Processing Record 36 of Set 7 | tokuyama
# Processing Record 37 of Set 7 | tautira
# Processing Record 38 of Set 7 | sedelnikovo
# City not found. Skipping...
# Processing Record 39 of Set 7 | madingou
# Processing Record 40 of Set 7 | comodoro rivadavia
# Processing Record 41 of Set 7 | sao jose da coroa grande
# Processing Record 42 of Set 7 | mount gambier
# Processing Record 43 of Set 7 | flinders
# Processing Record 44 of Set 7 | sibenik
# Processing Record 45 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 46 of Set 7 | samarai
# Processing Record 47 of Set 7 | tanete
# Processing Record 48 of Set 7 | treinta y tres
# Processing Record 49 of Set 7 | mendi
# Processing Record 50 of Set 7 | taltal
# Processing Record 1 of Set 8 | poitiers
# Processing Record 2 of Set 8 | centenario do sul
# Processing Record 3 of Set 8 | northam
# Processing Record 4 of Set 8 | saskylakh
# Processing Record 5 of Set 8 | labytnangi
# Processing Record 6 of Set 8 | mareeba
# Processing Record 7 of Set 8 | taoudenni
# Processing Record 8 of Set 8 | tevaitoa
# Processing Record 9 of Set 8 | henties bay
# Processing Record 10 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 8 | padang
# Processing Record 12 of Set 8 | la ronge
# Processing Record 13 of Set 8 | codrington
# Processing Record 14 of Set 8 | japura
# Processing Record 15 of Set 8 | nome
# Processing Record 16 of Set 8 | ndungu
# Processing Record 17 of Set 8 | najran
# Processing Record 18 of Set 8 | galesong
# Processing Record 19 of Set 8 | dumabato
# Processing Record 20 of Set 8 | payo
# Processing Record 21 of Set 8 | banda aceh
# Processing Record 22 of Set 8 | victoria
# Processing Record 23 of Set 8 | tarn taran
# Processing Record 24 of Set 8 | margate
# Processing Record 25 of Set 8 | tazovskiy
# Processing Record 26 of Set 8 | mineiros
# Processing Record 27 of Set 8 | erenhot
# Processing Record 28 of Set 8 | haines junction
# Processing Record 29 of Set 8 | barra do garcas
# Processing Record 30 of Set 8 | burnie
# Processing Record 31 of Set 8 | ranong
# Processing Record 32 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 33 of Set 8 | los llanos de aridane
# Processing Record 34 of Set 8 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 35 of Set 8 | marsaxlokk
# Processing Record 36 of Set 8 | robertson
# Processing Record 37 of Set 8 | fairbanks
# Processing Record 38 of Set 8 | sawakin
# Processing Record 39 of Set 8 | san patricio
# Processing Record 40 of Set 8 | shchelyayur
# City not found. Skipping...
# Processing Record 41 of Set 8 | shu
# Processing Record 42 of Set 8 | alim
# Processing Record 43 of Set 8 | airai
# Processing Record 44 of Set 8 | luderitz
# Processing Record 45 of Set 8 | saint-georges
# Processing Record 46 of Set 8 | tasiilaq
# Processing Record 47 of Set 8 | eyrarbakki
# Processing Record 48 of Set 8 | oranjemund
# Processing Record 49 of Set 8 | ambovombe
# Processing Record 50 of Set 8 | palmas
# Processing Record 1 of Set 9 | north bend
# Processing Record 2 of Set 9 | batagay-alyta
# Processing Record 3 of Set 9 | kindu
# Processing Record 4 of Set 9 | saint-pierre
# Processing Record 5 of Set 9 | evensk
# Processing Record 6 of Set 9 | hauterive
# Processing Record 7 of Set 9 | sao domingos do maranhao
# Processing Record 8 of Set 9 | cockburn town
# Processing Record 9 of Set 9 | kimbe
# Processing Record 10 of Set 9 | isangel
# Processing Record 11 of Set 9 | hervey bay
# Processing Record 12 of Set 9 | adrar
# Processing Record 13 of Set 9 | yerbogachen
# Processing Record 14 of Set 9 | manado
# Processing Record 15 of Set 9 | ust-omchug
# Processing Record 16 of Set 9 | adet
# Processing Record 17 of Set 9 | port hardy
# Processing Record 18 of Set 9 | pinawa
# Processing Record 19 of Set 9 | kondinskoye
# Processing Record 20 of Set 9 | lewiston
# Processing Record 21 of Set 9 | khandyga
# Processing Record 22 of Set 9 | opuwo
# Processing Record 23 of Set 9 | kropotkin
# Processing Record 24 of Set 9 | iracoubo
# Processing Record 25 of Set 9 | bud
# Processing Record 26 of Set 9 | ossora
# Processing Record 27 of Set 9 | omboue
# Processing Record 28 of Set 9 | kem
# Processing Record 29 of Set 9 | tual
# Processing Record 30 of Set 9 | tomatlan
# Processing Record 31 of Set 9 | tahta
# Processing Record 32 of Set 9 | rocha
# Processing Record 33 of Set 9 | turkmenabat
# Processing Record 34 of Set 9 | paamiut
# Processing Record 35 of Set 9 | salalah
# Processing Record 36 of Set 9 | yarmouth
# Processing Record 37 of Set 9 | viline
# Processing Record 38 of Set 9 | gobabis
# Processing Record 39 of Set 9 | kieta
# Processing Record 40 of Set 9 | obsharovka
# Processing Record 41 of Set 9 | general roca
# Processing Record 42 of Set 9 | boa vista
# Processing Record 43 of Set 9 | champerico
# Processing Record 44 of Set 9 | dicabisagan
# Processing Record 45 of Set 9 | ginda
# Processing Record 46 of Set 9 | bafra
# Processing Record 47 of Set 9 | nikolayevsk-na-amure
# Processing Record 48 of Set 9 | kutum
# Processing Record 49 of Set 9 | beringovskiy
# Processing Record 50 of Set 9 | sulangan
# Processing Record 1 of Set 10 | grindavik
# Processing Record 2 of Set 10 | gerede
# Processing Record 3 of Set 10 | vila velha
# Processing Record 4 of Set 10 | chilca
# Processing Record 5 of Set 10 | bakchar
# Processing Record 6 of Set 10 | swan hill
# Processing Record 7 of Set 10 | weihai
# Processing Record 8 of Set 10 | mackenzie
# Processing Record 9 of Set 10 | udachnyy
# Processing Record 10 of Set 10 | verkhniy baskunchak
# Processing Record 11 of Set 10 | nyuksenitsa
# Processing Record 12 of Set 10 | ekhabi
# Processing Record 13 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 10 | berlevag
# Processing Record 15 of Set 10 | coari
# Processing Record 16 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 10 | bandarbeyla
# Processing Record 18 of Set 10 | casa nova
# Processing Record 19 of Set 10 | uniao da victoria
# City not found. Skipping...
# Processing Record 20 of Set 10 | sabang
# Processing Record 21 of Set 10 | dalgopol
# Processing Record 22 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 10 | malumfashi
# Processing Record 24 of Set 10 | kalangala
# Processing Record 25 of Set 10 | yulara
# Processing Record 26 of Set 10 | makaryev
# Processing Record 27 of Set 10 | tiksi
# Processing Record 28 of Set 10 | santiago
# Processing Record 29 of Set 10 | riyadh
# Processing Record 30 of Set 10 | krasnoselkup
# Processing Record 31 of Set 10 | dire dawa
# Processing Record 32 of Set 10 | faya
# Processing Record 33 of Set 10 | bembereke
# Processing Record 34 of Set 10 | placido de castro
# Processing Record 35 of Set 10 | rabo de peixe
# Processing Record 36 of Set 10 | guerrero negro
# Processing Record 37 of Set 10 | leshukonskoye
# Processing Record 38 of Set 10 | baghdad
# Processing Record 39 of Set 10 | aswan
# Processing Record 40 of Set 10 | novikovo
# Processing Record 41 of Set 10 | kisanga
# Processing Record 42 of Set 10 | ishigaki
# Processing Record 43 of Set 10 | laiagam
# City not found. Skipping...
# Processing Record 44 of Set 10 | neuquen
# Processing Record 45 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 10 | kiunga
# Processing Record 47 of Set 10 | lebedinyy
# Processing Record 48 of Set 10 | jian
# Processing Record 49 of Set 10 | sao joao da barra
# Processing Record 50 of Set 10 | dunedin
# Processing Record 1 of Set 11 | sola
# Processing Record 2 of Set 11 | guymon
# Processing Record 3 of Set 11 | jishou
# Processing Record 4 of Set 11 | pontian kecil
# Processing Record 5 of Set 11 | tiznit
# Processing Record 6 of Set 11 | ouadda
# Processing Record 7 of Set 11 | dukat
# Processing Record 8 of Set 11 | kailua
# Processing Record 9 of Set 11 | grand baie
# Processing Record 10 of Set 11 | dolores
# Processing Record 11 of Set 11 | manavalakurichi
# Processing Record 12 of Set 11 | arona
# Processing Record 13 of Set 11 | kalmunai
# Processing Record 14 of Set 11 | zhangye
# Processing Record 15 of Set 11 | hasaki
# Processing Record 16 of Set 11 | aksu
# Processing Record 17 of Set 11 | srandakan
# Processing Record 18 of Set 11 | svetlaya
# Processing Record 19 of Set 11 | vestmannaeyjar
# Processing Record 20 of Set 11 | moree
# Processing Record 21 of Set 11 | sakaiminato
# Processing Record 22 of Set 11 | ancud
# Processing Record 23 of Set 11 | nekhayevskiy
# Processing Record 24 of Set 11 | wuwei
# Processing Record 25 of Set 11 | joao camara
# Processing Record 26 of Set 11 | kuusamo
# Processing Record 27 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 11 | alyangula
# Processing Record 29 of Set 11 | yashan
# Processing Record 30 of Set 11 | kargasok
# Processing Record 31 of Set 11 | hadrut
# Processing Record 32 of Set 11 | mantua
# Processing Record 33 of Set 11 | port alberni
# Processing Record 34 of Set 11 | nakusp
# Processing Record 35 of Set 11 | nikolayevskaya
# Processing Record 36 of Set 11 | sorland
# Processing Record 37 of Set 11 | eyl
# Processing Record 38 of Set 11 | izhma
# Processing Record 39 of Set 11 | collie
# Processing Record 40 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 11 | tanout
# Processing Record 42 of Set 11 | manthani
# Processing Record 43 of Set 11 | morant bay
# Processing Record 44 of Set 11 | mabaruma
# Processing Record 45 of Set 11 | hokitika
# Processing Record 46 of Set 11 | lexington
# Processing Record 47 of Set 11 | ust-tsilma
# Processing Record 48 of Set 11 | nuuk
# Processing Record 49 of Set 11 | marsabit
# Processing Record 50 of Set 11 | qasigiannguit
# Processing Record 1 of Set 12 | geraldton
# Processing Record 2 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 3 of Set 12 | auki
# Processing Record 4 of Set 12 | witrivier
# City not found. Skipping...
# Processing Record 5 of Set 12 | manaure
# Processing Record 6 of Set 12 | terney
# Processing Record 7 of Set 12 | kochetok
# Processing Record 8 of Set 12 | san cristobal
# Processing Record 9 of Set 12 | marienburg
# Processing Record 10 of Set 12 | fergus falls
# Processing Record 11 of Set 12 | toora-khem
# Processing Record 12 of Set 12 | anadyr
# Processing Record 13 of Set 12 | upata
# Processing Record 14 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 15 of Set 12 | salto del guaira
# Processing Record 16 of Set 12 | bizhbulyak
# Processing Record 17 of Set 12 | biak
# Processing Record 18 of Set 12 | chipinge
# Processing Record 19 of Set 12 | cabinda
# Processing Record 20 of Set 12 | quatre cocos
# Processing Record 21 of Set 12 | tambacounda
# Processing Record 22 of Set 12 | vera cruz
# Processing Record 23 of Set 12 | clinton
# Processing Record 24 of Set 12 | biltine
# Processing Record 25 of Set 12 | lavrentiya
# Processing Record 26 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 12 | jacareacanga
# Processing Record 28 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 30 of Set 12 | belozerskoye
# Processing Record 31 of Set 12 | bratsk
# Processing Record 32 of Set 12 | kupang
# Processing Record 33 of Set 12 | eenhana
# Processing Record 34 of Set 12 | ust-nera
# Processing Record 35 of Set 12 | sampit
# Processing Record 36 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 37 of Set 12 | ugoofaaru
# Processing Record 38 of Set 12 | conway
# Processing Record 39 of Set 12 | veinte de noviembre
# Processing Record 40 of Set 12 | hungen
# Processing Record 41 of Set 12 | darnah
# Processing Record 42 of Set 12 | kununurra
# Processing Record 43 of Set 12 | beyneu
# Processing Record 44 of Set 12 | aloleng
# Processing Record 45 of Set 12 | okato
# Processing Record 46 of Set 12 | mumford
# Processing Record 47 of Set 12 | khomeynishahr
# City not found. Skipping...
# Processing Record 48 of Set 12 | vila franca do campo
# Processing Record 49 of Set 12 | lujan
# Processing Record 50 of Set 12 | barstow
# Processing Record 1 of Set 13 | kruisfontein
# Processing Record 2 of Set 13 | puerto baquerizo moreno
# Processing Record 3 of Set 13 | chapais
# Processing Record 4 of Set 13 | aklavik
# Processing Record 5 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 6 of Set 13 | alberton
# Processing Record 7 of Set 13 | hobyo
# Processing Record 8 of Set 13 | minden
# Processing Record 9 of Set 13 | buala
# Processing Record 10 of Set 13 | geresk
# City not found. Skipping...
# Processing Record 11 of Set 13 | amapa
# Processing Record 12 of Set 13 | constantine
# Processing Record 13 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 14 of Set 13 | lasa
# Processing Record 15 of Set 13 | roebourne
# Processing Record 16 of Set 13 | colac
# Processing Record 17 of Set 13 | davis
# Processing Record 18 of Set 13 | manzhouli
# Processing Record 19 of Set 13 | blagodatnoye
# Processing Record 20 of Set 13 | nalbari
# Processing Record 21 of Set 13 | kayerkan
# Processing Record 22 of Set 13 | gimli
# Processing Record 23 of Set 13 | boyabat
# Processing Record 24 of Set 13 | galveston
# Processing Record 25 of Set 13 | vanavara
# Processing Record 26 of Set 13 | kihei
# Processing Record 27 of Set 13 | kiama
# Processing Record 28 of Set 13 | gat
# Processing Record 29 of Set 13 | caravelas
# Processing Record 30 of Set 13 | kangar
# Processing Record 31 of Set 13 | ninghai
# Processing Record 32 of Set 13 | carlos barbosa
# Processing Record 33 of Set 13 | springbok
# Processing Record 34 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 35 of Set 13 | zholymbet
# Processing Record 36 of Set 13 | salekhard
# Processing Record 37 of Set 13 | tilichiki
# Processing Record 38 of Set 13 | blackwater
# Processing Record 39 of Set 13 | las vegas
# Processing Record 40 of Set 13 | sao felix do xingu
# Processing Record 41 of Set 13 | karratha
# Processing Record 42 of Set 13 | kilmez
# City not found. Skipping...
# Processing Record 43 of Set 13 | petrolandia
# City not found. Skipping...
# Processing Record 44 of Set 13 | sao jose dos pinhais
# Processing Record 45 of Set 13 | san vicente
# Processing Record 46 of Set 13 | stephenville
# Processing Record 47 of Set 13 | payson
# Processing Record 48 of Set 13 | festus
# Processing Record 49 of Set 13 | anito
# Processing Record 50 of Set 13 | lazaro cardenas
# Processing Record 1 of Set 14 | sakata
# Processing Record 2 of Set 14 | port moresby
# Processing Record 3 of Set 14 | valdivia
# Processing Record 4 of Set 14 | ojinaga
# Processing Record 5 of Set 14 | california city
# Processing Record 6 of Set 14 | valday
# Processing Record 7 of Set 14 | karwar
# Processing Record 8 of Set 14 | kushiro
# Processing Record 9 of Set 14 | lunenburg
# Processing Record 10 of Set 14 | babu
# Processing Record 11 of Set 14 | mehamn
# Processing Record 12 of Set 14 | duz
# City not found. Skipping...
# Processing Record 13 of Set 14 | mulanje
# Processing Record 14 of Set 14 | half moon bay
# Processing Record 15 of Set 14 | okhotsk
# Processing Record 16 of Set 14 | latiano
# Processing Record 17 of Set 14 | srednekolymsk
# Processing Record 18 of Set 14 | la paz
# Processing Record 19 of Set 14 | urucara
# Processing Record 20 of Set 14 | pakxan
# Processing Record 21 of Set 14 | ayagoz
# Processing Record 22 of Set 14 | fukue
# Processing Record 23 of Set 14 | spirit river
# Processing Record 24 of Set 14 | necochea
# Processing Record 25 of Set 14 | mushie
# Processing Record 26 of Set 14 | natal
# Processing Record 27 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 28 of Set 14 | kudahuvadhoo
# Processing Record 29 of Set 14 | oktyabrskiy
# Processing Record 30 of Set 14 | hirara
# Processing Record 31 of Set 14 | narrabri
# Processing Record 32 of Set 14 | ranfurly
# Processing Record 33 of Set 14 | namatanai
# Processing Record 34 of Set 14 | saint anthony
# Processing Record 35 of Set 14 | sisimiut
# Processing Record 36 of Set 14 | lorengau
# Processing Record 37 of Set 14 | caucaia
# Processing Record 38 of Set 14 | misratah
# Processing Record 39 of Set 14 | prince rupert
# Processing Record 40 of Set 14 | ambulu
# Processing Record 41 of Set 14 | pokrovka
# Processing Record 42 of Set 14 | banjarmasin
# Processing Record 43 of Set 14 | dalvik
# Processing Record 44 of Set 14 | loukhi
# Processing Record 45 of Set 14 | ramtek
# Processing Record 46 of Set 14 | basco
# Processing Record 47 of Set 14 | borogontsy
# Processing Record 48 of Set 14 | dakoro
# Processing Record 49 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 50 of Set 14 | kjollefjord
# Processing Record 1 of Set 15 | marsa matruh
# Processing Record 2 of Set 15 | paredon
# Processing Record 3 of Set 15 | shimoda
# Processing Record 4 of Set 15 | esperance
# Processing Record 5 of Set 15 | jiayuguan
# Processing Record 6 of Set 15 | boyolangu
# Processing Record 7 of Set 15 | kandrian
# Processing Record 8 of Set 15 | louis trichardt
# Processing Record 9 of Set 15 | cody
# Processing Record 10 of Set 15 | medea
# Processing Record 11 of Set 15 | capaci
# Processing Record 12 of Set 15 | mackay
# Processing Record 13 of Set 15 | morondava
# Processing Record 14 of Set 15 | shenzhen
# Processing Record 15 of Set 15 | panama city
# Processing Record 16 of Set 15 | manacapuru
# Processing Record 17 of Set 15 | akyab
# Processing Record 18 of Set 15 | acarau
# Processing Record 19 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 20 of Set 15 | lhokseumawe
# Processing Record 21 of Set 15 | nador
# Processing Record 22 of Set 15 | klaksvik
# Processing Record 23 of Set 15 | valera
# Processing Record 24 of Set 15 | acajutla
# Processing Record 25 of Set 15 | popondetta
# Processing Record 26 of Set 15 | harnosand
# Processing Record 27 of Set 15 | ub
# City not found. Skipping...
# Processing Record 28 of Set 15 | kawana waters
# City not found. Skipping...
# Processing Record 29 of Set 15 | arlit
# Processing Record 30 of Set 15 | pagudpud
# Processing Record 31 of Set 15 | sheridan
# Processing Record 32 of Set 15 | mandalgovi
# Processing Record 33 of Set 15 | antigonish
# Processing Record 34 of Set 15 | san policarpo
# Processing Record 35 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 36 of Set 15 | maltahohe
# Processing Record 37 of Set 15 | ketchikan
# Processing Record 38 of Set 15 | adjumani
# Processing Record 39 of Set 15 | roald
# Processing Record 40 of Set 15 | labrea
# Processing Record 41 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 42 of Set 15 | westport
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 680

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Atuona  -9.8000 -139.0333     76.51        78          40       22.86
# 1     Kaiyuan  23.6977  103.3037     72.50        83          74        1.74
# 2        Juba   4.8517   31.5825     67.66        96          89        1.97
# 3      Albany  42.6001  -73.9662     76.41        80           3        6.26
# 4    Tessalit  20.1986    1.0114     89.56        34         100       10.29
# 5     Rikitea -23.1203 -134.9692     73.44        75           8       20.76
# 6       Bukan  36.5210   46.2089     73.81        53           0        3.60
# 7      Kodiak  57.7900 -152.4072     65.71        39           0        4.61
# 8  Nouadhibou  20.9310  -17.0347     73.38        78           4       24.16
# 9   Dharchula  29.8500   80.5333     72.34        93         100        0.22
#
#   Country                 Date
# 0      PF  2022-07-29 01:24:52
# 1      CN  2022-07-29 01:24:53
# 2      SS  2022-07-29 01:24:53
# 3      US  2022-07-29 01:22:08
# 4      ML  2022-07-29 01:24:53
# 5      PF  2022-07-29 01:22:42
# 6      IR  2022-07-29 01:24:54
# 7      US  2022-07-29 01:24:54
# 8      MR  2022-07-29 01:24:54
# 9      IN  2022-07-29 01:24:55

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country                 Date      Lat       Lng  Max Temp  \
# 0      Atuona      PF  2022-07-29 01:24:52  -9.8000 -139.0333     76.51
# 1     Kaiyuan      CN  2022-07-29 01:24:53  23.6977  103.3037     72.50
# 2        Juba      SS  2022-07-29 01:24:53   4.8517   31.5825     67.66
# 3      Albany      US  2022-07-29 01:22:08  42.6001  -73.9662     76.41
# 4    Tessalit      ML  2022-07-29 01:24:53  20.1986    1.0114     89.56
# 5     Rikitea      PF  2022-07-29 01:22:42 -23.1203 -134.9692     73.44
# 6       Bukan      IR  2022-07-29 01:24:54  36.5210   46.2089     73.81
# 7      Kodiak      US  2022-07-29 01:24:54  57.7900 -152.4072     65.71
# 8  Nouadhibou      MR  2022-07-29 01:24:54  20.9310  -17.0347     73.38
# 9   Dharchula      IN  2022-07-29 01:24:55  29.8500   80.5333     72.34
#
#    Humidity  Cloudiness  Wind Speed
# 0        78          40       22.86
# 1        83          74        1.74
# 2        96          89        1.97
# 3        80           3        6.26
# 4        34         100       10.29
# 5        75           8       20.76
# 6        53           0        3.60
# 7        39           0        4.61
# 8        78           4       24.16
# 9        93         100        0.22

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
